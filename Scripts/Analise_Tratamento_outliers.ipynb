# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_excel("../Bases/Base_filtrada_idade.xlsx")

# %% [markdown]
# ## Analise Inicial

# %%
colunas_numericas = ['V0022', 'A02305', 'A02306', 'C008', 'P00104', 'P035', 'P03701', 'P03702', 
                     'P053', 'P05901', 'P05902', 'P05903', 'P05904']

# %%
base
# Out:
#        V0001    V0024    UPA_PNS  V0006_PNS  V0022  A02201  A02305  A02306  \
# 0         11  1110011  110000016          2      4       1     1.0     0.0
# 1         11  1110011  110000016          3      8       1     1.0     1.0
# 2         11  1110011  110000016          5      2       2     NaN     NaN
# 3         11  1110011  110000016          7      3       1     0.0     8.0
# 4         11  1110011  110000016          8      4       1     0.0     1.0
# ...      ...      ...        ...        ...    ...     ...     ...     ...
# 54012     53  5310220  530044434          6      5       1     0.0     2.0
# 54013     53  5310220  530044434          8      6       1     1.0     2.0
# 54014     53  5310220  530044434         10      2       1     1.0     2.0
# 54015     53  5310220  530044434         11      4       1     2.0     4.0
# 54016     53  5310220  530044434         13      1       1     0.0     2.0
#
#        C00301  C004  ...  P052  P053  P05901  P05902  P05903  P05904  Q074  \
# 0           4     5  ...   NaN  12.0     NaN     NaN     NaN     NaN     2
# 1           1     1  ...   1.0  18.0    25.0     0.0     0.0     0.0     2
# 2           1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 3           1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 4           2     2  ...   NaN  24.0     NaN     NaN     NaN     NaN     2
# ...       ...   ...  ...   ...   ...     ...     ...     ...     ...   ...
# 54012       2     2  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 54013       1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     1
# 54014       2    14  ...   NaN  39.0     NaN     NaN     NaN     NaN     2
# 54015       1     1  ...   1.0  15.0    10.0     0.0     0.0     0.0     2
# 54016       1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
#
#        Q092  Q11006  Q11604
# 0         2       2       2
# 1         2       2       2
# 2         2       2       2
# 3         2       2       2
# 4         2       2       2
# ...     ...     ...     ...
# 54012     2       2       2
# 54013     2       2       2
# 54014     2       2       2
# 54015     2       2       2
# 54016     2       2       2
#
# [54017 rows x 33 columns]

# %%
base.describe()
# Out:
#               V0001         V0024       UPA_PNS     V0006_PNS         V0022  \
# count  54017.000000  5.401700e+04  5.401700e+04  54017.000000  54017.000000
# mean      29.091638  2.940800e+06  2.909929e+08      7.408483      3.339356
# std       11.904726  1.189150e+06  1.190679e+08      4.116774      1.521617
# min       11.000000  1.110011e+06  1.100000e+08      1.000000      1.000000
# 25%       21.000000  2.152021e+06  2.100531e+08      4.000000      2.000000
# 50%       27.000000  2.753022e+06  2.700492e+08      7.000000      3.000000
# 75%       35.000000  3.551011e+06  3.504881e+08     11.000000      4.000000
# max       53.000000  5.310220e+06  5.300511e+08     18.000000     23.000000
#
#              A02201        A02305        A02306        C00301         C004  \
# count  54017.000000  32613.000000  32613.000000  54017.000000  54017.00000
# mean       1.396246      0.680373      1.504124      1.629431      2.21969
# std        0.489121      1.391087      1.463178      0.974814      2.32993
# min        1.000000      0.000000      0.000000      1.000000      1.00000
# 25%        1.000000      0.000000      1.000000      1.000000      1.00000
# 50%        1.000000      0.000000      1.000000      1.000000      1.00000
# 75%        2.000000      1.000000      2.000000      2.000000      2.00000
# max        2.000000     36.000000     21.000000     12.000000     19.00000
#
#        ...         P052          P053        P05901        P05902  \
# count  ...  47625.00000  14704.000000  10392.000000  10392.000000
# mean   ...      2.59727     16.571545     11.379811      1.127983
# std    ...      0.78077      4.949481      9.046772      2.518105
# min    ...      1.00000      3.000000      0.000000      0.000000
# 25%    ...      3.00000     14.000000      4.000000      0.000000
# 50%    ...      3.00000     16.000000     10.000000      0.000000
# 75%    ...      3.00000     18.000000     18.000000      0.000000
# max    ...      3.00000     50.000000     47.000000     11.000000
#
#              P05903        P05904          Q074          Q092        Q11006  \
# count  10392.000000  10392.000000  54017.000000  54017.000000  54017.000000
# mean       0.185431      0.239319      1.947165      1.921580      1.940408
# std        0.607881      0.917637      0.223706      0.268833      0.236732
# min        0.000000      0.000000      1.000000      1.000000      1.000000
# 25%        0.000000      0.000000      2.000000      2.000000      2.000000
# 50%        0.000000      0.000000      2.000000      2.000000      2.000000
# 75%        0.000000      0.000000      2.000000      2.000000      2.000000
# max        3.000000      6.000000      2.000000      2.000000      2.000000
#
#              Q11604
# count  54017.000000
# mean       1.991077
# std        0.094041
# min        1.000000
# 25%        2.000000
# 50%        2.000000
# 75%        2.000000
# max        2.000000
#
# [8 rows x 33 columns]

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54017 entries, 0 to 54016
# Data columns (total 33 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      54017 non-null  int64
#  1   V0024      54017 non-null  int64
#  2   UPA_PNS    54017 non-null  int64
#  3   V0006_PNS  54017 non-null  int64
#  4   V0022      54017 non-null  int64
#  5   A02201     54017 non-null  int64
#  6   A02305     32613 non-null  float64
#  7   A02306     32613 non-null  float64
#  8   C00301     54017 non-null  int64
#  9   C004       54017 non-null  int64
#  10  C006       54017 non-null  int64
#  11  C008       54017 non-null  int64
#  12  C009       54017 non-null  int64
#  13  L01701     0 non-null      float64
#  14  L018       0 non-null      float64
#  15  M01601     54017 non-null  int64
#  16  N010       54017 non-null  int64
#  17  P00104     53135 non-null  float64
#  18  P034       54017 non-null  int64
#  19  P035       24777 non-null  float64
#  20  P03701     23870 non-null  float64
#  21  P03702     23870 non-null  float64
#  22  P050       54017 non-null  int64
#  23  P052       47625 non-null  float64
#  24  P053       14704 non-null  float64
#  25  P05901     10392 non-null  float64
#  26  P05902     10392 non-null  float64
#  27  P05903     10392 non-null  float64
#  28  P05904     10392 non-null  float64
#  29  Q074       54017 non-null  int64
#  30  Q092       54017 non-null  int64
#  31  Q11006     54017 non-null  int64
#  32  Q11604     54017 non-null  int64
# dtypes: float64(14), int64(19)
# memory usage: 13.6 MB

# %% [markdown]
# ### Visualização dos outliers

# %%
Q1 = base[colunas_numericas].quantile(0.25)
Q3 = base[colunas_numericas].quantile(0.75)
IQR = Q3 - Q1

# %%
limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# %%
outliers = ((base[colunas_numericas] < limite_inferior) | (base[colunas_numericas] > limite_superior)).sum()
print("\nNúmero de outliers por atributo (método IQR):")
print(outliers)
# Out:
# Número de outliers por atributo (método IQR):
# V0022      752
# A02305    2235
# A02306    2402
# C008         0
# P00104     880
# P035         0
# P03701    9804
# P03702       0
# P053      1193
# P05901      63
# P05902    2419
# P05903    1019
# P05904     938
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=base[colunas_numericas])
plt.xticks(rotation=45)
plt.title('Boxplots para Identificação de Outliers')
plt.show()

# %% [markdown]
# ## Tratamento dos outliers

# %%
colunas_tratar = ['A02305', 'A02306', 'P03701', 'V0022', 'P053']

Q1 = base[colunas_tratar].quantile(0.25)
Q3 = base[colunas_tratar].quantile(0.75)
IQR = Q3 - Q1

limite_inferior = Q1 - 1.5 * IQR
limite_superior = Q3 + 1.5 * IQR

# %%
outliers = base[(base[colunas_tratar] < limite_inferior) | (base[colunas_tratar] > limite_superior)].any(axis=1)

# %%
base_outliers = base[outliers]
base_outliers
# Out:
#        V0001    V0024    UPA_PNS  V0006_PNS  V0022  A02201  A02305  A02306  \
# 1         11  1110011  110000016          3      8       1     1.0     1.0
# 3         11  1110011  110000016          7      3       1     0.0     8.0
# 5         11  1110011  110000016          9      2       1     0.0     2.0
# 7         11  1110011  110000016         15      5       1     2.0     0.0
# 8         11  1110011  110000034          1      4       1     8.0     8.0
# ...      ...      ...        ...        ...    ...     ...     ...     ...
# 54009     53  5310220  530041727         15      3       1     6.0     5.0
# 54010     53  5310220  530044434          2      1       1     3.0     5.0
# 54011     53  5310220  530044434          3      2       1     0.0     8.0
# 54014     53  5310220  530044434         10      2       1     1.0     2.0
# 54015     53  5310220  530044434         11      4       1     2.0     4.0
#
#        C00301  C004  ...  P052  P053  P05901  P05902  P05903  P05904  Q074  \
# 1           1     1  ...   1.0  18.0    25.0     0.0     0.0     0.0     2
# 3           1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 5           1     1  ...   2.0   NaN     2.0     0.0     0.0     0.0     2
# 7           5    10  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 8           3     4  ...   2.0   NaN     0.0     1.0     0.0     0.0     2
# ...       ...   ...  ...   ...   ...     ...     ...     ...     ...   ...
# 54009       1     1  ...   NaN  17.0     NaN     NaN     NaN     NaN     2
# 54010       1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 54011       2     2  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 54014       2    14  ...   NaN  39.0     NaN     NaN     NaN     NaN     2
# 54015       1     1  ...   1.0  15.0    10.0     0.0     0.0     0.0     2
#
#        Q092  Q11006  Q11604
# 1         2       2       2
# 3         2       2       2
# 5         2       2       2
# 7         2       2       2
# 8         2       2       2
# ...     ...     ...     ...
# 54009     2       2       2
# 54010     2       2       2
# 54011     2       2       2
# 54014     2       2       2
# 54015     2       2       2
#
# [10722 rows x 33 columns]

# %%
base.drop(index=base_outliers.index, inplace=True)

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 43295 entries, 0 to 54016
# Data columns (total 33 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      43295 non-null  int64
#  1   V0024      43295 non-null  int64
#  2   UPA_PNS    43295 non-null  int64
#  3   V0006_PNS  43295 non-null  int64
#  4   V0022      43295 non-null  int64
#  5   A02201     43295 non-null  int64
#  6   A02305     24580 non-null  float64
#  7   A02306     24580 non-null  float64
#  8   C00301     43295 non-null  int64
#  9   C004       43295 non-null  int64
#  10  C006       43295 non-null  int64
#  11  C008       43295 non-null  int64
#  12  C009       43295 non-null  int64
#  13  L01701     0 non-null      float64
#  14  L018       0 non-null      float64
#  15  M01601     43295 non-null  int64
#  16  N010       43295 non-null  int64
#  17  P00104     42520 non-null  float64
#  18  P034       43295 non-null  int64
#  19  P035       17628 non-null  float64
#  20  P03701     16839 non-null  float64
#  21  P03702     16839 non-null  float64
#  22  P050       43295 non-null  int64
#  23  P052       38604 non-null  float64
#  24  P053       11059 non-null  float64
#  25  P05901     8008 non-null   float64
#  26  P05902     8008 non-null   float64
#  27  P05903     8008 non-null   float64
#  28  P05904     8008 non-null   float64
#  29  Q074       43295 non-null  int64
#  30  Q092       43295 non-null  int64
#  31  Q11006     43295 non-null  int64
#  32  Q11604     43295 non-null  int64
# dtypes: float64(14), int64(19)
# memory usage: 11.2 MB

# %%
base
# Out:
#        V0001    V0024    UPA_PNS  V0006_PNS  V0022  A02201  A02305  A02306  \
# 0         11  1110011  110000016          2      4       1     1.0     0.0
# 2         11  1110011  110000016          5      2       2     NaN     NaN
# 4         11  1110011  110000016          8      4       1     0.0     1.0
# 6         11  1110011  110000016         12      1       1     0.0     2.0
# 9         11  1110011  110000034          4      3       2     NaN     NaN
# ...      ...      ...        ...        ...    ...     ...     ...     ...
# 54006     53  5310220  530041727         12      4       1     0.0     2.0
# 54008     53  5310220  530041727         14      3       2     NaN     NaN
# 54012     53  5310220  530044434          6      5       1     0.0     2.0
# 54013     53  5310220  530044434          8      6       1     1.0     2.0
# 54016     53  5310220  530044434         13      1       1     0.0     2.0
#
#        C00301  C004  ...  P052  P053  P05901  P05902  P05903  P05904  Q074  \
# 0           4     5  ...   NaN  12.0     NaN     NaN     NaN     NaN     2
# 2           1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 4           2     2  ...   NaN  24.0     NaN     NaN     NaN     NaN     2
# 6           1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 9           1     1  ...   2.0   NaN     1.0     0.0     0.0     0.0     2
# ...       ...   ...  ...   ...   ...     ...     ...     ...     ...   ...
# 54006       1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 54008       1     1  ...   NaN  12.0     NaN     NaN     NaN     NaN     2
# 54012       2     2  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
# 54013       1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     1
# 54016       1     1  ...   3.0   NaN     NaN     NaN     NaN     NaN     2
#
#        Q092  Q11006  Q11604
# 0         2       2       2
# 2         2       2       2
# 4         2       2       2
# 6         2       2       2
# 9         1       2       2
# ...     ...     ...     ...
# 54006     2       2       2
# 54008     2       2       2
# 54012     2       2       2
# 54013     2       2       2
# 54016     2       2       2
#
# [43295 rows x 33 columns]

# %%
base.to_excel("../Bases/Base_sem_outlier.xlsx", index=False)
