# %%
import pandas as pd

# %%
data = pd.read_excel("../Bases/Base_sem_vazios.xlsx")

# %%
data
# Out:
#        V0001    V0024    UPA_PNS  V0006_PNS  V0022  A02201|A02305|A02306  \
# 0         11  1110011  110000016          2      4                     1
# 1         11  1110011  110000016          5      2                     0
# 2         11  1110011  110000016          8      4                     1
# 3         11  1110011  110000016         12      1                     2
# 4         11  1110011  110000034          4      3                     0
# ...      ...      ...        ...        ...    ...                   ...
# 43011     53  5310220  530041727         12      4                     2
# 43012     53  5310220  530041727         14      3                     0
# 43013     53  5310220  530044434          6      5                     2
# 43014     53  5310220  530044434          8      6                     3
# 43015     53  5310220  530044434         13      1                     2
#
#        C00301  C004  C006  C008  ...  P00404  P034|P035  P03701|P03702  \
# 0           4     5     2    19  ...   152.0          0    Não pratica
# 1           1     1     2    28  ...   176.0          1          31-60
# 2           2     2     2    38  ...   156.0          0    Não pratica
# 3           1     1     1    36  ...   172.0          2          61-90
# 4           1     1     1    42  ...   185.0          3         91-120
# ...       ...   ...   ...   ...  ...     ...        ...            ...
# 43011       1     1     1    41  ...   159.0          0    Não pratica
# 43012       1     1     1    21  ...   178.0          0    Não pratica
# 43013       2     2     1    44  ...   162.0          0    Não pratica
# 43014       1     1     2    26  ...   150.0          0    Não pratica
# 43015       1     1     1    32  ...   186.0          1          61-90
#
#        P050|P052       P053  P05901|P05902|P05903|P05904  Q074  Q092 Q11006  \
# 0              1  12.000000              Fuma atualmente     2     2      2
# 1              4  -1.000000                  Nunca fumou     2     2      2
# 2              2  24.000000              Fuma atualmente     2     2      2
# 3              4  -1.000000                  Nunca fumou     2     2      2
# 4              3  15.733784                          1-5     2     1      2
# ...          ...        ...                          ...   ...   ...    ...
# 43011          4  -1.000000                  Nunca fumou     2     2      2
# 43012          1  12.000000              Fuma atualmente     2     2      2
# 43013          4  -1.000000                  Nunca fumou     2     2      2
# 43014          4  -1.000000                  Nunca fumou     1     2      2
# 43015          4  -1.000000                  Nunca fumou     2     2      2
#
#        Q11604
# 0           2
# 1           2
# 2           2
# 3           2
# 4           2
# ...       ...
# 43011       2
# 43012       2
# 43013       2
# 43014       2
# 43015       2
#
# [43016 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43016 entries, 0 to 43015
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   V0001                        43016 non-null  int64
#  1   V0024                        43016 non-null  int64
#  2   UPA_PNS                      43016 non-null  int64
#  3   V0006_PNS                    43016 non-null  int64
#  4   V0022                        43016 non-null  int64
#  5   A02201|A02305|A02306         43016 non-null  int64
#  6   C00301                       43016 non-null  int64
#  7   C004                         43016 non-null  int64
#  8   C006                         43016 non-null  int64
#  9   C008                         43016 non-null  int64
#  10  C009                         43016 non-null  int64
#  11  L01701                       0 non-null      float64
#  12  L018                         0 non-null      float64
#  13  M01601                       43016 non-null  int64
#  14  N010                         43016 non-null  int64
#  15  P00104                       43016 non-null  float64
#  16  P00404                       43016 non-null  float64
#  17  P034|P035                    43016 non-null  int64
#  18  P03701|P03702                43016 non-null  object
#  19  P050|P052                    43016 non-null  int64
#  20  P053                         43016 non-null  float64
#  21  P05901|P05902|P05903|P05904  43016 non-null  object
#  22  Q074                         43016 non-null  int64
#  23  Q092                         43016 non-null  int64
#  24  Q11006                       43016 non-null  int64
#  25  Q11604                       43016 non-null  int64
# dtypes: float64(5), int64(19), object(2)
# memory usage: 8.5+ MB

# %% [markdown]
# ## Exclusão de colunas

# %%
data.drop(columns=['L01701', 'L018'], inplace=True)

# %% [markdown]
# ## Criação e alteração de colunas

# %% [markdown]
# ### IMC

# %%
data[['P00104', 'P00404']]
# Out:
#        P00104  P00404
# 0        65.0   152.0
# 1        55.0   176.0
# 2        60.0   156.0
# 3        80.0   172.0
# 4        95.0   185.0
# ...       ...     ...
# 43011    74.0   159.0
# 43012    64.0   178.0
# 43013    62.0   162.0
# 43014    75.0   150.0
# 43015    62.0   186.0
#
# [43016 rows x 2 columns]

# %%
data['IMC'] = data['P00104']/((data['P00404']/100)**2)

# %%
data['IMC']
# Out:
# 0        28.133657
# 1        17.755682
# 2        24.654832
# 3        27.041644
# 4        27.757487
#            ...
# 43011    29.270994
# 43012    20.199470
# 43013    23.624447
# 43014    33.333333
# 43015    17.921147
# Name: IMC, Length: 43016, dtype: float64

# %% [markdown]
# separacao do IMC em faixas, valores das faixas foram retiradas dos dados da OMS

# %%
bins = [0, 18.49, 24.99, 29.99, 34.99, 39.99, 100]
labels = ['Abaixo do peso', 'Eitrófico', 'Sobrepeso', 'Obesidade grau 1', 'Obesidade grau 2', 'Obesidade grau 3']

data['IMC'] = pd.cut(data['IMC'], bins=bins, labels=labels, right=False)

# %%
data.loc[data['IMC'] == 'Obesidade grau 3']
# Out:
#        V0001    V0024    UPA_PNS  V0006_PNS  V0022  A02201|A02305|A02306  \
# 104       11  1110011  110008539         11      5                     2
# 187       11  1110011  110013678         12      4                     0
# 228       11  1110011  110017901          6      5                     4
# 230       11  1110011  110017901         11      5                     3
# 330       11  1110012  110006766          8      3                     0
# ...      ...      ...        ...        ...    ...                   ...
# 42654     53  5310211  530049339          3      3                     1
# 42666     53  5310211  530051067          5      6                     2
# 42831     53  5310212  530036730          2      4                     0
# 42932     53  5310213  530031739          2      4                     0
# 43008     53  5310220  530041727          5      3                     2
#
#        C00301  C004  C006  C008  ...  P034|P035  P03701|P03702  P050|P052  \
# 104         3     4     1    25  ...          7          61-90          3
# 187         1     1     2    36  ...          0    Não pratica          4
# 228         1     1     2    39  ...          0    Não pratica          4
# 230         2     2     1    44  ...          1          61-90          3
# 330         1     1     1    27  ...          0    Não pratica          3
# ...       ...   ...   ...   ...  ...        ...            ...        ...
# 42654       1     1     2    34  ...          3         91-120          4
# 42666       1     1     2    46  ...          7          61-90          3
# 42831       1     1     2    27  ...          0    Não pratica          4
# 42932       1     1     1    30  ...          0    Não pratica          3
# 43008       1     1     2    35  ...          0    Não pratica          4
#
#        P053  P05901|P05902|P05903|P05904  Q074 Q092  Q11006  Q11604  \
# 104    15.0                          15+     2    2       2       2
# 187    -1.0                  Nunca fumou     2    2       2       2
# 228    -1.0                  Nunca fumou     2    2       2       2
# 230    12.0                         5-15     2    2       2       2
# 330    10.0                         5-15     1    2       2       2
# ...     ...                          ...   ...  ...     ...     ...
# 42654  -1.0                  Nunca fumou     2    2       2       2
# 42666  16.0                          15+     2    2       2       2
# 42831  -1.0                  Nunca fumou     2    2       2       2
# 42932  14.0                          15+     2    2       1       2
# 43008  -1.0                  Nunca fumou     2    2       2       2
#
#                     IMC
# 104    Obesidade grau 3
# 187    Obesidade grau 3
# 228    Obesidade grau 3
# 230    Obesidade grau 3
# 330    Obesidade grau 3
# ...                 ...
# 42654  Obesidade grau 3
# 42666  Obesidade grau 3
# 42831  Obesidade grau 3
# 42932  Obesidade grau 3
# 43008  Obesidade grau 3
#
# [533 rows x 25 columns]

# %% [markdown]
# ### P053

# %% [markdown]
# faixas de valores definidas pelo artigo P Vineis

# %%
data[['P050|P052','P053']]
# Out:
#        P050|P052       P053
# 0              1  12.000000
# 1              4  -1.000000
# 2              2  24.000000
# 3              4  -1.000000
# 4              3  15.733784
# ...          ...        ...
# 43011          4  -1.000000
# 43012          1  12.000000
# 43013          4  -1.000000
# 43014          4  -1.000000
# 43015          4  -1.000000
#
# [43016 rows x 2 columns]

# %%
data['P053'].value_counts()
# Out:
# P053
# -1.000000     30407
#  15.000000     1712
#  15.733784     1527
#  18.000000     1396
#  16.000000     1276
#  14.000000     1116
#  17.000000     1028
#  12.000000      863
#  20.000000      849
#  13.000000      806
#  19.000000      459
#  10.000000      419
#  22.000000      217
#  8.000000       176
#  11.000000      168
#  23.000000      155
#  21.000000      143
#  9.000000       117
#  15.504732      103
#  24.000000       79
# Name: count, dtype: int64

# %%
bins = [-1, 0, 12, 16, 20, 100]
labels = ['Nunca fumou', '<=12', '13-16', '17-20', '21+']

data['P053'] = pd.cut(data['P053'], bins=bins, labels=labels, right=False)

# %%
data[['P050|P052','P053']]
# Out:
#        P050|P052         P053
# 0              1        13-16
# 1              4  Nunca fumou
# 2              2          21+
# 3              4  Nunca fumou
# 4              3        13-16
# ...          ...          ...
# 43011          4  Nunca fumou
# 43012          1        13-16
# 43013          4  Nunca fumou
# 43014          4  Nunca fumou
# 43015          4  Nunca fumou
#
# [43016 rows x 2 columns]

# %% [markdown]
# ## Salvando

# %%
data
# Out:
#        V0001    V0024    UPA_PNS  V0006_PNS  V0022  A02201|A02305|A02306  \
# 0         11  1110011  110000016          2      4                     1
# 1         11  1110011  110000016          5      2                     0
# 2         11  1110011  110000016          8      4                     1
# 3         11  1110011  110000016         12      1                     2
# 4         11  1110011  110000034          4      3                     0
# ...      ...      ...        ...        ...    ...                   ...
# 43011     53  5310220  530041727         12      4                     2
# 43012     53  5310220  530041727         14      3                     0
# 43013     53  5310220  530044434          6      5                     2
# 43014     53  5310220  530044434          8      6                     3
# 43015     53  5310220  530044434         13      1                     2
#
#        C00301  C004  C006  C008  ...  P034|P035  P03701|P03702  P050|P052  \
# 0           4     5     2    19  ...          0    Não pratica          1
# 1           1     1     2    28  ...          1          31-60          4
# 2           2     2     2    38  ...          0    Não pratica          2
# 3           1     1     1    36  ...          2          61-90          4
# 4           1     1     1    42  ...          3         91-120          3
# ...       ...   ...   ...   ...  ...        ...            ...        ...
# 43011       1     1     1    41  ...          0    Não pratica          4
# 43012       1     1     1    21  ...          0    Não pratica          1
# 43013       2     2     1    44  ...          0    Não pratica          4
# 43014       1     1     2    26  ...          0    Não pratica          4
# 43015       1     1     1    32  ...          1          61-90          4
#
#               P053  P05901|P05902|P05903|P05904  Q074 Q092  Q11006 Q11604  \
# 0            13-16              Fuma atualmente     2    2       2      2
# 1      Nunca fumou                  Nunca fumou     2    2       2      2
# 2              21+              Fuma atualmente     2    2       2      2
# 3      Nunca fumou                  Nunca fumou     2    2       2      2
# 4            13-16                          1-5     2    1       2      2
# ...            ...                          ...   ...  ...     ...    ...
# 43011  Nunca fumou                  Nunca fumou     2    2       2      2
# 43012        13-16              Fuma atualmente     2    2       2      2
# 43013  Nunca fumou                  Nunca fumou     2    2       2      2
# 43014  Nunca fumou                  Nunca fumou     1    2       2      2
# 43015  Nunca fumou                  Nunca fumou     2    2       2      2
#
#                     IMC
# 0             Sobrepeso
# 1        Abaixo do peso
# 2             Eitrófico
# 3             Sobrepeso
# 4             Sobrepeso
# ...                 ...
# 43011         Sobrepeso
# 43012         Eitrófico
# 43013         Eitrófico
# 43014  Obesidade grau 1
# 43015    Abaixo do peso
#
# [43016 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43016 entries, 0 to 43015
# Data columns (total 25 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   V0001                        43016 non-null  int64
#  1   V0024                        43016 non-null  int64
#  2   UPA_PNS                      43016 non-null  int64
#  3   V0006_PNS                    43016 non-null  int64
#  4   V0022                        43016 non-null  int64
#  5   A02201|A02305|A02306         43016 non-null  int64
#  6   C00301                       43016 non-null  int64
#  7   C004                         43016 non-null  int64
#  8   C006                         43016 non-null  int64
#  9   C008                         43016 non-null  int64
#  10  C009                         43016 non-null  int64
#  11  M01601                       43016 non-null  int64
#  12  N010                         43016 non-null  int64
#  13  P00104                       43016 non-null  float64
#  14  P00404                       43016 non-null  float64
#  15  P034|P035                    43016 non-null  int64
#  16  P03701|P03702                43016 non-null  object
#  17  P050|P052                    43016 non-null  int64
#  18  P053                         43016 non-null  category
#  19  P05901|P05902|P05903|P05904  43016 non-null  object
#  20  Q074                         43016 non-null  int64
#  21  Q092                         43016 non-null  int64
#  22  Q11006                       43016 non-null  int64
#  23  Q11604                       43016 non-null  int64
#  24  IMC                          43016 non-null  category
# dtypes: category(2), float64(2), int64(19), object(2)
# memory usage: 7.6+ MB

# %%
data.to_excel("../Bases/Base_tratada.xlsx", index=False)
