# %%
import pandas as pd

# %%
import_columns = ['V0001', 'V0024', 'UPA_PNS', 'V0006_PNS', 'V0022', 'C00301', 'C004', 'A02201', 'A02305', 'A02306', 'C006', 
                  'C008', 'C009', 'L01701', 'L018', 'M01601', 'N010', 'P00102', 'P00104','P034', 'P035', 
                  'P03701', 'P03702', 'P050', 'P052', 'P053', 'P05401', 'P05404',  
                  'P05407', 'P05410', 'P05413',
                  'P05416', 'P05419', 'P058', 
                  'P05901', 'P05902', 'P05903', 'P05904', 'Q09201', 'Q11006', 'Q11604', 'W001', 'W00101', 'W00102',
                  'W00103', 'Q074']

# %%
base = pd.read_csv("../Bases/pns2019.csv", usecols=import_columns)

# %%
base
# Out:
#         V0001    V0024    UPA_PNS  V0006_PNS  V0022  A02201  A02305  A02306  \
# 0          11  1110011  110000016          1    6.0     1.0     0.0     2.0
# 1          11  1110011  110000016          1    6.0     1.0     0.0     2.0
# 2          11  1110011  110000016          1    6.0     1.0     0.0     2.0
# 3          11  1110011  110000016          1    6.0     1.0     0.0     2.0
# 4          11  1110011  110000016          1    6.0     1.0     0.0     2.0
# ...       ...      ...        ...        ...    ...     ...     ...     ...
# 293721     53  5310220  530044434         14    4.0     1.0     2.0     4.0
# 293722     53  5310220  530044434         14    4.0     1.0     2.0     4.0
# 293723     53  5310220  530044434         14    4.0     1.0     2.0     4.0
# 293724     53  5310220  530044434         14    4.0     1.0     2.0     4.0
# 293725     53  5310220  530044434         15    NaN     NaN     NaN     NaN
#
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293726 entries, 0 to 293725
# Data columns (total 46 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   V0001      293726 non-null  int64
#  1   V0024      293726 non-null  int64
#  2   UPA_PNS    293726 non-null  int64
#  3   V0006_PNS  293726 non-null  int64
#  4   V0022      279382 non-null  float64
#  5   A02201     279382 non-null  float64
#  6   A02305     177894 non-null  float64
#  7   A02306     177894 non-null  float64
#  8   C00301     279382 non-null  float64
#  9   C004       279382 non-null  float64
#  10  C006       279382 non-null  float64
#  11  C008       279382 non-null  float64
#  12  C009       279382 non-null  float64
#  13  L01701     6632 non-null    float64
#  14  L018       293 non-null     float64
#  15  M01601     90846 non-null   float64
#  16  N010       90846 non-null   float64
#  17  P00102     90846 non-null   float64
# ...

# %%
base.dropna(subset=['Q074'], inplace=True)

# %%
base
# Out:
#         V0001    V0024    UPA_PNS  V0006_PNS  V0022  A02201  A02305  A02306  \
# 0          11  1110011  110000016          1    6.0     1.0     0.0     2.0
# 9          11  1110011  110000016          2    4.0     1.0     1.0     0.0
# 10         11  1110011  110000016          3    8.0     1.0     1.0     1.0
# 18         11  1110011  110000016          4    1.0     1.0     0.0     1.0
# 19         11  1110011  110000016          5    2.0     2.0     NaN     NaN
# ...       ...      ...        ...        ...    ...     ...     ...     ...
# 293709     53  5310220  530044434          9    3.0     1.0     1.0     4.0
# 293712     53  5310220  530044434         10    2.0     1.0     1.0     2.0
# 293713     53  5310220  530044434         11    4.0     1.0     2.0     4.0
# 293718     53  5310220  530044434         12    3.0     1.0     6.0    11.0
# 293720     53  5310220  530044434         13    1.0     1.0     0.0     2.0
#
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 90846 entries, 0 to 293720
# Data columns (total 46 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      90846 non-null  int64
#  1   V0024      90846 non-null  int64
#  2   UPA_PNS    90846 non-null  int64
#  3   V0006_PNS  90846 non-null  int64
#  4   V0022      90846 non-null  float64
#  5   A02201     90846 non-null  float64
#  6   A02305     53905 non-null  float64
#  7   A02306     53905 non-null  float64
#  8   C00301     90846 non-null  float64
#  9   C004       90846 non-null  float64
#  10  C006       90846 non-null  float64
#  11  C008       90846 non-null  float64
#  12  C009       90846 non-null  float64
#  13  L01701     0 non-null      float64
#  14  L018       0 non-null      float64
#  15  M01601     90846 non-null  float64
#  16  N010       90846 non-null  float64
#  17  P00102     90846 non-null  float64
#  18  P00104     89954 non-null  float64
# ...

# %%
base = base[base['C008'] <= 50]

# %%
base['C008'].value_counts()
# Out:
# C008
# 37.0    1990
# 39.0    1904
# 36.0    1882
# 35.0    1833
# 38.0    1820
# 40.0    1798
# 34.0    1787
# 33.0    1776
# 30.0    1756
# 42.0    1749
# 43.0    1745
# 32.0    1721
# 41.0    1700
# 31.0    1681
# 46.0    1660
# 49.0    1642
# 44.0    1612
# 45.0    1597
# 48.0    1593
# 50.0    1556
# 29.0    1555
# 27.0    1522
# 47.0    1506
# 28.0    1450
# 24.0    1378
# 25.0    1371
# 26.0    1351
# 23.0    1259
# 22.0    1212
# 21.0    1168
# 20.0    1107
# 19.0    1045
# 18.0     976
# 17.0     852
# 16.0     756
# 15.0     707
# Name: count, dtype: int64

# %%
base.loc[base['Q074'] == 1, 'C008'].value_counts()
# Out:
# C008
# 31.0    100
# 27.0    100
# 35.0     98
# 34.0     95
# 39.0     92
# 33.0     92
# 41.0     92
# 37.0     90
# 42.0     90
# 20.0     89
# 43.0     89
# 32.0     87
# 25.0     87
# 28.0     84
# 29.0     84
# 38.0     83
# 40.0     81
# 36.0     81
# 30.0     80
# 44.0     78
# 24.0     77
# 47.0     75
# 46.0     74
# 18.0     73
# 45.0     73
# 49.0     72
# 22.0     71
# 19.0     71
# 21.0     70
# 23.0     66
# 48.0     66
# 26.0     63
# 17.0     61
# 15.0     59
# 50.0     58
# 16.0     53
# Name: count, dtype: int64

# %%
base
# Out:
#         V0001    V0024    UPA_PNS  V0006_PNS  V0022  A02201  A02305  A02306  \
# 9          11  1110011  110000016          2    4.0     1.0     1.0     0.0
# 10         11  1110011  110000016          3    8.0     1.0     1.0     1.0
# 19         11  1110011  110000016          5    2.0     2.0     NaN     NaN
# 22         11  1110011  110000016          7    3.0     1.0     0.0     8.0
# 26         11  1110011  110000016          8    4.0     1.0     0.0     1.0
# ...       ...      ...        ...        ...    ...     ...     ...     ...
# 293697     53  5310220  530044434          6    5.0     1.0     0.0     2.0
# 293702     53  5310220  530044434          8    6.0     1.0     1.0     2.0
# 293712     53  5310220  530044434         10    2.0     1.0     1.0     2.0
# 293713     53  5310220  530044434         11    4.0     1.0     2.0     4.0
# 293720     53  5310220  530044434         13    1.0     1.0     0.0     2.0
#
# ...

# %%
base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 54017 entries, 9 to 293720
# Data columns (total 46 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      54017 non-null  int64
#  1   V0024      54017 non-null  int64
#  2   UPA_PNS    54017 non-null  int64
#  3   V0006_PNS  54017 non-null  int64
#  4   V0022      54017 non-null  float64
#  5   A02201     54017 non-null  float64
#  6   A02305     32613 non-null  float64
#  7   A02306     32613 non-null  float64
#  8   C00301     54017 non-null  float64
#  9   C004       54017 non-null  float64
#  10  C006       54017 non-null  float64
#  11  C008       54017 non-null  float64
#  12  C009       54017 non-null  float64
#  13  L01701     0 non-null      float64
#  14  L018       0 non-null      float64
#  15  M01601     54017 non-null  float64
#  16  N010       54017 non-null  float64
#  17  P00102     54017 non-null  float64
#  18  P00104     53135 non-null  float64
# ...

# %%
base.to_excel("../Base_filtrada_idade.xlsx", index=False)
